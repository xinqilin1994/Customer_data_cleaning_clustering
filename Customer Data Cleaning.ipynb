# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly as py
import plotly.graph_objs as go
from sklearn.cluster import KMeans
import warnings
import os
warnings.filterwarnings("ignore")
py.offline.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
customer = pd.read_csv("SC_data.csv")
print(customer.shape)
customer.head()
# Out:
# (34544, 26)
#   PNRLocatorID     TicketNum  CouponSeqNbr ServiceStartCity ServiceEndCity  \
# 0       AADJKH  3.377510e+12             1              SFO            MSP
# 1       AADJKH  3.377510e+12             2              MSP            SFO
# 2       AAFCUE  3.377510e+12             2              MCO            MSP
# 3       AAFCUE  3.377510e+12             1              MSP            MCO
# 4       AAFDZS  3.377410e+12             2              LAX            MSP
#
#   PNRCreateDate ServiceStartDate PaxName  \
# 0    11/10/2014        12/8/2014  SHORLE
# 1    11/10/2014       12/11/2014  SHORLE
# 2     12/1/2014       12/21/2014  SOEFEV
# 3     12/1/2014       12/17/2014  SOEFEV
# 4     10/9/2014       10/30/2014  NEUMJO
#
#                                        EncryptedName GenderCode  ...  \
# 0  53484F52455944696420493F7C20676574207468697320...          F  ...
# 1  53484F52455944696420493F7C20676574207468697320...          F  ...
# 2  534F4546464B455244696420493F7C2067657420746869...          M  ...
# 3  534F4546464B455244696420493F7C2067657420746869...          M  ...
# 4  4E45554D414E44696420493F7C20676574207468697320...          M  ...
#
#    BaseFareAmt  TotalDocAmt UFlyRewardsNumber UflyMemberStatus CardHolder  \
# 0       230.70        276.2               NaN              NaN        NaN
# 1       230.70        276.2               NaN              NaN        NaN
# 2       308.75          0.0               NaN              NaN        NaN
# 3       308.75          0.0               NaN              NaN        NaN
# 4       139.54        178.2       196189803.0         Standard      False
#
#   BookedProduct  EnrollDate  MarketingFlightNbr  MarketingAirlineCode  \
# 0           NaN         NaN                 392                    SY
# 1           NaN         NaN                 395                    SY
# 2          DSNY         NaN                 342                    SY
# 3          DSNY         NaN                 341                    SY
# 4           NaN     39:04.0                 422                    SY
#
#   StopoverCode
# 0          NaN
# 1            O
# 2            O
# 3          NaN
# 4            O
#
# [5 rows x 26 columns]

# %%
customer.dtypes
# Out:
# PNRLocatorID             object
# TicketNum               float64
# CouponSeqNbr              int64
# ServiceStartCity         object
# ServiceEndCity           object
# PNRCreateDate            object
# ServiceStartDate         object
# PaxName                  object
# EncryptedName            object
# GenderCode               object
# birthdateid             float64
# Age                     float64
# PostalCode               object
# BkdClassOfService        object
# TrvldClassOfService      object
# BookingChannel           object
# BaseFareAmt             float64
# TotalDocAmt             float64
# UFlyRewardsNumber       float64
# UflyMemberStatus         object
# CardHolder               object
# BookedProduct            object
# EnrollDate               object
# MarketingFlightNbr        int64
# MarketingAirlineCode     object
# StopoverCode             object
# dtype: object

# %%
customer.isnull().sum()
# Out:
# PNRLocatorID                0
# TicketNum                   0
# CouponSeqNbr                0
# ServiceStartCity            0
# ServiceEndCity              0
# PNRCreateDate               0
# ServiceStartDate            0
# PaxName                     0
# EncryptedName               0
# GenderCode                164
# birthdateid               164
# Age                       164
# PostalCode              27183
# BkdClassOfService           0
# TrvldClassOfService         0
# BookingChannel              0
# BaseFareAmt                 0
# TotalDocAmt                 0
# UFlyRewardsNumber       27153
# UflyMemberStatus        27153
# CardHolder              27153
# BookedProduct           22379
# EnrollDate              27153
# MarketingFlightNbr          0
# MarketingAirlineCode        0
# StopoverCode            17307
# dtype: int64

# %%
customer.describe()
# Out:
#           TicketNum  CouponSeqNbr   birthdateid           Age   BaseFareAmt  \
# count  3.454400e+04  34544.000000  34380.000000  34380.000000  34544.000000
# mean   3.374290e+12      1.459385  44856.944968     40.403287    287.018126
# std    2.571218e+09      0.565820   6890.659919     18.855714    180.113575
# min    3.372050e+12      1.000000  18139.000000      0.000000      0.000000
# 25%    3.372110e+12      1.000000  39591.000000     26.000000    174.880000
# 50%    3.372110e+12      1.000000  44814.000000     40.000000    273.870000
# 75%    3.377290e+12      2.000000  50025.000000     55.000000    368.720000
# max    3.377560e+12      6.000000  59917.000000    114.000000   1744.000000
#
#         TotalDocAmt  UFlyRewardsNumber  MarketingFlightNbr
# count  34544.000000       7.391000e+03        34544.000000
# mean     317.322380       2.042285e+08          365.547534
# std      214.492038       1.495937e+07          238.485626
# min        0.000000       1.000018e+08          100.000000
# 25%      194.000000       2.007800e+08          251.000000
# 50%      307.000000       2.029959e+08          351.000000
# 75%      415.400000       2.103695e+08          471.000000
# max     5275.000000       2.410847e+08         8877.000000

# %%
## only keep records with known gender, birthdate and age.
customer = customer.dropna(axis=0, subset=['GenderCode', 'birthdateid', 'Age'])

# %%
## assign 0 to rewards number if it's null
customer['UFlyRewardsNumber'].fillna(0, inplace = True)

# %%
## assign non-ufly to member status if it's null
customer['UflyMemberStatus'].fillna("non-ufly", inplace = True)

# %%
## Discard duplicate records
customer.drop_duplicates(subset = ["PNRLocatorID","CouponSeqNbr","PaxName","ServiceStartCity","ServiceEndCity","ServiceStartDate"], keep = False, inplace = True)

# %%
customer.shape
# Out:
# (31575, 26)

# %%
customer.groupby("BookingChannel").count()
# Out:
#                       PNRLocatorID  TicketNum  CouponSeqNbr  ServiceStartCity  \
# BookingChannel
# DFW                             11         11            11                11
# FCM                             27         27            27                27
# HRL                              1          1             1                 1
# JFK                              1          1             1                 1
# LAN                              4          4             4                 4
# LAS                              1          1             1                 1
# LAX                              1          1             1                 1
# MKE                              2          2             2                 2
# MSP                             36         36            36                36
# Outside Booking              14054      14054         14054             14054
# PHX                              1          1             1                 1
# RSW                              2          2             2                 2
# Reservations Booking          1162       1162          1162              1162
# SCA Website Booking          14211      14211         14211             14211
# SFO                              2          2             2                 2
# SY Vacation                    948        948           948               948
# Tour Operator Portal          1105       1105          1105              1105
# UFO                              2          2             2                 2
# XTM                              4          4             4                 4
#
#                       ServiceEndCity  PNRCreateDate  ServiceStartDate  \
# BookingChannel
# DFW                               11             11                11
# FCM                               27             27                27
# HRL                                1              1                 1
# JFK                                1              1                 1
# LAN                                4              4                 4
# LAS                                1              1                 1
# LAX                                1              1                 1
# MKE                                2              2                 2
# MSP                               36             36                36
# Outside Booking                14054          14054             14054
# PHX                                1              1                 1
# RSW                                2              2                 2
# Reservations Booking            1162           1162              1162
# SCA Website Booking            14211          14211             14211
# SFO                                2              2                 2
# SY Vacation                      948            948               948
# Tour Operator Portal            1105           1105              1105
# UFO                                2              2                 2
# XTM                                4              4                 4
#
#                       PaxName  EncryptedName  GenderCode  ...  BaseFareAmt  \
# BookingChannel                                            ...
# DFW                        11             11          11  ...           11
# FCM                        27             27          27  ...           27
# HRL                         1              1           1  ...            1
# JFK                         1              1           1  ...            1
# LAN                         4              4           4  ...            4
# LAS                         1              1           1  ...            1
# LAX                         1              1           1  ...            1
# MKE                         2              2           2  ...            2
# MSP                        36             36          36  ...           36
# Outside Booking         14054          14054       14054  ...        14054
# PHX                         1              1           1  ...            1
# RSW                         2              2           2  ...            2
# Reservations Booking     1162           1162        1162  ...         1162
# SCA Website Booking     14211          14211       14211  ...        14211
# SFO                         2              2           2  ...            2
# SY Vacation               948            948         948  ...          948
# Tour Operator Portal     1105           1105        1105  ...         1105
# UFO                         2              2           2  ...            2
# XTM                         4              4           4  ...            4
#
#                       TotalDocAmt  UFlyRewardsNumber  UflyMemberStatus  \
# BookingChannel
# DFW                            11                 11                11
# FCM                            27                 27                27
# HRL                             1                  1                 1
# JFK                             1                  1                 1
# LAN                             4                  4                 4
# LAS                             1                  1                 1
# LAX                             1                  1                 1
# MKE                             2                  2                 2
# MSP                            36                 36                36
# Outside Booking             14054              14054             14054
# PHX                             1                  1                 1
# RSW                             2                  2                 2
# Reservations Booking         1162               1162              1162
# SCA Website Booking         14211              14211             14211
# SFO                             2                  2                 2
# SY Vacation                   948                948               948
# Tour Operator Portal         1105               1105              1105
# UFO                             2                  2                 2
# XTM                             4                  4                 4
#
#                       CardHolder  BookedProduct  EnrollDate  \
# BookingChannel
# DFW                            0             10           0
# FCM                           25             22          25
# HRL                            0              0           0
# JFK                            0              1           0
# LAN                            0              0           0
# LAS                            0              0           0
# LAX                            0              1           0
# MKE                            0              2           0
# MSP                            0             17           0
# Outside Booking             1348           2972        1348
# PHX                            0              1           0
# RSW                            0              0           0
# Reservations Booking         349            324         349
# SCA Website Booking         4872           5220        4872
# SFO                            0              0           0
# SY Vacation                  207            769         207
# Tour Operator Portal          50           1105          50
# UFO                            0              0           0
# XTM                            0              4           0
#
#                       MarketingFlightNbr  MarketingAirlineCode  StopoverCode
# BookingChannel
# DFW                                   11                    11             5
# FCM                                   27                    27             8
# HRL                                    1                     1             0
# JFK                                    1                     1             0
# LAN                                    4                     4             3
# LAS                                    1                     1             0
# LAX                                    1                     1             0
# MKE                                    2                     2             1
# MSP                                   36                    36             8
# Outside Booking                    14054                 14054          8472
# PHX                                    1                     1             0
# RSW                                    2                     2             0
# Reservations Booking                1162                  1162           418
# SCA Website Booking                14211                 14211          5837
# SFO                                    2                     2             0
# SY Vacation                          948                   948           473
# Tour Operator Portal                1105                  1105           546
# UFO                                    2                     2             0
# XTM                                    4                     4             0
#
# [19 rows x 25 columns]

# %%
# Replace odd one off booking channels with 'Other'
customer.loc[~customer['BookingChannel'].isin(['Outside Booking', 'Reservations Booking', 'SCA Website Booking', 'SY Vacation', 'Tour Operator Portal']), 'BookingChannel'] = 'Other'

# %%
customer.groupby("BookingChannel").count()
# Out:
#                       PNRLocatorID  TicketNum  CouponSeqNbr  ServiceStartCity  \
# BookingChannel
# Other                           95         95            95                95
# Outside Booking              14054      14054         14054             14054
# Reservations Booking          1162       1162          1162              1162
# SCA Website Booking          14211      14211         14211             14211
# SY Vacation                    948        948           948               948
# Tour Operator Portal          1105       1105          1105              1105
#
#                       ServiceEndCity  PNRCreateDate  ServiceStartDate  \
# BookingChannel
# Other                             95             95                95
# Outside Booking                14054          14054             14054
# Reservations Booking            1162           1162              1162
# SCA Website Booking            14211          14211             14211
# SY Vacation                      948            948               948
# Tour Operator Portal            1105           1105              1105
#
#                       PaxName  EncryptedName  GenderCode  ...  BaseFareAmt  \
# BookingChannel                                            ...
# Other                      95             95          95  ...           95
# Outside Booking         14054          14054       14054  ...        14054
# Reservations Booking     1162           1162        1162  ...         1162
# SCA Website Booking     14211          14211       14211  ...        14211
# SY Vacation               948            948         948  ...          948
# Tour Operator Portal     1105           1105        1105  ...         1105
#
#                       TotalDocAmt  UFlyRewardsNumber  UflyMemberStatus  \
# BookingChannel
# Other                          95                 95                95
# Outside Booking             14054              14054             14054
# Reservations Booking         1162               1162              1162
# SCA Website Booking         14211              14211             14211
# SY Vacation                   948                948               948
# Tour Operator Portal         1105               1105              1105
#
#                       CardHolder  BookedProduct  EnrollDate  \
# BookingChannel
# Other                         25             58          25
# Outside Booking             1348           2972        1348
# Reservations Booking         349            324         349
# SCA Website Booking         4872           5220        4872
# SY Vacation                  207            769         207
# Tour Operator Portal          50           1105          50
#
#                       MarketingFlightNbr  MarketingAirlineCode  StopoverCode
# BookingChannel
# Other                                 95                    95            25
# Outside Booking                    14054                 14054          8472
# Reservations Booking                1162                  1162           418
# SCA Website Booking                14211                 14211          5837
# SY Vacation                          948                   948           473
# Tour Operator Portal                1105                  1105           546
#
# [6 rows x 25 columns]

# %%
customer.groupby('MarketingAirlineCode').count()
# Out:
#                       PNRLocatorID  TicketNum  CouponSeqNbr  ServiceStartCity  \
# MarketingAirlineCode
# F9                              24         24            24                24
# SY                           31551      31551         31551             31551
#
#                       ServiceEndCity  PNRCreateDate  ServiceStartDate  \
# MarketingAirlineCode
# F9                                24             24                24
# SY                             31551          31551             31551
#
#                       PaxName  EncryptedName  GenderCode  ...  BookingChannel  \
# MarketingAirlineCode                                      ...
# F9                         24             24          24  ...              24
# SY                      31551          31551       31551  ...           31551
#
#                       BaseFareAmt  TotalDocAmt  UFlyRewardsNumber  \
# MarketingAirlineCode
# F9                             24           24                 24
# SY                          31551        31551              31551
#
#                       UflyMemberStatus  CardHolder  BookedProduct  EnrollDate  \
# MarketingAirlineCode
# F9                                  24           0              0           0
# SY                               31551        6851          10448        6851
#
#                       MarketingFlightNbr  StopoverCode
# MarketingAirlineCode
# F9                                    24            23
# SY                                 31551         15748
#
# [2 rows x 25 columns]

# %%
# Only keep records that involve SunCountry airlines tickets, for which MarketingAirlineCode=="SY".
SY_customer = customer.loc[customer['MarketingAirlineCode'] == 'SY']

# %%
SY_customer.shape
# Out:
# (31551, 26)

# %%
group = SY_customer

# %%
group['min'] = group.groupby('PNRLocatorID')['CouponSeqNbr'].transform('min')
group
# Out:
#       PNRLocatorID     TicketNum  CouponSeqNbr ServiceStartCity  \
# 0           AADJKH  3.377510e+12             1              SFO
# 1           AADJKH  3.377510e+12             2              MSP
# 2           AAFCUE  3.377510e+12             2              MCO
# 3           AAFCUE  3.377510e+12             1              MSP
# 4           AAFDZS  3.377410e+12             2              LAX
# 5           AAFDZS  3.377410e+12             1              MSP
# 6           AAJWOU  3.372110e+12             1              SEA
# 7           AAMRWP  3.377470e+12             1              MSP
# 8           AAMSHL  3.372110e+12             1              MSP
# 9           AAMSHL  3.372110e+12             2              MCO
# 10          AAMVUK  3.372110e+12             1              LAX
# 11          AARXZC  3.377420e+12             1              MDW
# 12          AALWHR  3.372110e+12             1              MSP
# 17          AAMCBX  3.372110e+12             2              LAN
# 18          AAMCBX  3.372110e+12             1              DCA
# 19          AAMRWO  3.377190e+12             2              SFO
# 20          AAMRWO  3.377190e+12             1              MSP
# 21          AAMRWO  3.377190e+12             2              SFO
# 22          AAMRWO  3.377190e+12             1              MSP
# 23          AANKKX  3.377400e+12             1              MSP
# 24          AASNWT  3.372110e+12             2              CUN
# 25          AASNWT  3.372110e+12             1              MSP
# 26          AASNWT  3.372110e+12             2              CUN
# 27          AASNWT  3.372110e+12             1              MSP
# 28          AAOJKC  3.377430e+12             1              LAX
# 29          AAOJKC  3.377430e+12             2              MSP
# 30          AAMSHL  3.372110e+12             1              MSP
# 31          AAMSHL  3.372110e+12             2              MCO
# 34          ABABOI  3.372110e+12             1              MSP
# 35          ABABOI  3.372110e+12             2              LAX
# ...            ...           ...           ...              ...
# 34510       ZYARLL  3.372110e+12             2              MSP
# 34511       ZYARLL  3.372110e+12             1              LAX
# 34512       ZYLEEN  3.372110e+12             2              MCO
# 34513       ZYLEEN  3.372110e+12             1              MSP
# 34514       ZYLEEN  3.372110e+12             1              MSP
# 34515       ZYLEEN  3.372110e+12             2              MCO
# 34516       ZYGJQE  3.372110e+12             1              MSP
# 34517       ZYGJQE  3.372110e+12             2              DFW
# 34518       ZYQUXM  3.377360e+12             1              MSP
# 34519       ZYQUXM  3.377360e+12             2              LAS
# 34520       ZYVNYU  3.372110e+12             1              MSP
# 34521       ZYVNYU  3.372110e+12             2              CUN
# 34526       ZYVNYU  3.372110e+12             2              CUN
# 34527       ZYVNYU  3.372110e+12             1              MSP
# 34528       ZZCRKI  3.372110e+12             1              LAX
# 34529       ZZCRKI  3.372110e+12             2              MSP
# 34530       ZZECGS  3.372110e+12             1              DFW
# 34531       ZZECGS  3.372110e+12             2              CUN
# 34532       ZZECGS  3.372110e+12             2              CUN
# 34533       ZZECGS  3.372110e+12             1              DFW
# 34534       ZZKSPB  3.372110e+12             1              MSP
# 34535       ZZPTUB  3.377280e+12             1              LAX
# 34536       ZZQRES  3.372110e+12             1              MSP
# 34537       ZZQRES  3.372110e+12             1              MSP
# 34538       ZZYKXU  3.372110e+12             2              MCO
# 34539       ZZYKXU  3.372110e+12             1              MSP
# 34540       ZZYKXU  3.372110e+12             1              MSP
# 34541       ZZYKXU  3.372110e+12             2              MCO
# 34542       ZZYKXU  3.372110e+12             1              MSP
# 34543       ZZYKXU  3.372110e+12             2              MCO
#
#       ServiceEndCity PNRCreateDate ServiceStartDate PaxName  \
# 0                MSP    11/10/2014        12/8/2014  SHORLE
# 1                SFO    11/10/2014       12/11/2014  SHORLE
# 2                MSP     12/1/2014       12/21/2014  SOEFEV
# 3                MCO     12/1/2014       12/17/2014  SOEFEV
# 4                MSP     10/9/2014       10/30/2014  NEUMJO
# 5                LAX     10/9/2014       10/27/2014  NEUMJO
# 6                MSP      5/4/2013         5/4/2013  GEDDER
# 7                LAX     7/14/2014        7/25/2014  DUONUY
# 8                MCO     11/5/2014        12/3/2014  PEREDA
# 9                MSP     11/5/2014        12/7/2014  PEREDA
# 10               MSP      6/3/2013         6/3/2013  WELLSA
# 11               MSP     6/17/2014        6/21/2014  NELSLO
# 12               PHX    10/24/2014       12/27/2014  ASHTJO
# 17               DCA    10/31/2013       11/29/2013   YAOTI
# 18               LAN    10/31/2013       11/25/2013   YAOTI
# 19               MSP    12/18/2012         2/6/2013  FRENMI
# 20               SFO    12/18/2012         2/1/2013  FRENMI
# 21               MSP    12/18/2012         2/6/2013  FRENKA
# 22               SFO    12/18/2012         2/1/2013  FRENKA
# 23               SEA     4/10/2014        5/23/2014  PETENI
# 24               MSP      7/3/2013         2/8/2014  KALINI
# 25               CUN      7/3/2013         2/3/2014  KALINI
# 26               MSP      7/3/2013         2/8/2014  NELSDO
# 27               CUN      7/3/2013         2/3/2014  NELSDO
# 28               MSP     8/31/2014         9/2/2014  BINDNA
# 29               BOS     8/31/2014         9/2/2014  BINDNA
# 30               MCO     11/5/2014        12/3/2014  CABRJE
# 31               MSP     11/5/2014        12/7/2014  CABRJE
# 34               LAX     5/16/2013        7/19/2013  MILLDA
# 35               MSP     5/16/2013        7/26/2013  MILLDA
# ...              ...           ...              ...     ...
# 34510            LAX      7/5/2013         9/9/2013  SIMOJO
# 34511            MSP      7/5/2013         9/4/2013  SIMOJO
# 34512            MSP     5/23/2013        8/10/2013  CONNMA
# 34513            MCO     5/23/2013         8/3/2013  CONNMA
# 34514            MCO     5/23/2013         8/3/2013  CONNER
# 34515            MSP     5/23/2013        8/10/2013  CONNER
# 34516            DFW      2/6/2014        2/16/2014  BROWSU
# 34517            MSP      2/6/2014        2/20/2014  BROWSU
# 34518            LAS      3/3/2014        4/27/2014  DIXOAM
# 34519            MSP      3/3/2014         5/1/2014  DIXOAM
# 34520            CUN     10/2/2013        3/13/2014  MEHRSC
# 34521            MSP     10/2/2013        3/20/2014  MEHRSC
# 34526            MSP     10/2/2013        3/20/2014  MEHRKA
# 34527            CUN     10/2/2013        3/13/2014  MEHRKA
# 34528            MSP     5/15/2013        6/27/2013  CHALLY
# 34529            LAX     5/15/2013         7/2/2013  CHALLY
# 34530            CUN     9/15/2014        9/25/2014  BREEAV
# 34531            DFW     9/15/2014        9/28/2014  BREEAV
# 34532            DFW     9/15/2014        9/28/2014  BREETA
# 34533            CUN     9/15/2014        9/25/2014  BREETA
# 34534            DCA      8/5/2014        9/19/2014  YANGYO
# 34535            MSP     6/18/2013        7/31/2013  MONTPA
# 34536            RSW     5/26/2014       10/24/2014  UNGEBA
# 34537            RSW     5/26/2014       10/24/2014  UNGERI
# 34538            MSP     6/18/2014       10/18/2014  TALMDE
# 34539            MCO     6/18/2014       10/12/2014  TALMDE
# 34540            MCO     6/18/2014       10/12/2014  TALMAN
# 34541            MSP     6/18/2014       10/18/2014  TALMAN
# 34542            MCO     6/18/2014       10/12/2014  TALMWI
# 34543            MSP     6/18/2014       10/18/2014  TALMWI
#
#                                            EncryptedName GenderCode  ...  \
# 0      53484F52455944696420493F7C20676574207468697320...          F  ...
# 1      53484F52455944696420493F7C20676574207468697320...          F  ...
# 2      534F4546464B455244696420493F7C2067657420746869...          M  ...
# 3      534F4546464B455244696420493F7C2067657420746869...          M  ...
# 4      4E45554D414E44696420493F7C20676574207468697320...          M  ...
# 5      4E45554D414E44696420493F7C20676574207468697320...          M  ...
# 6      474544444544696420493F7C2067657420746869732072...          M  ...
# 7      44554F4E4744696420493F7C2067657420746869732072...          F  ...
# 8      504552455A52414D4952455344696420493F7C20676574...          F  ...
# 9      504552455A52414D4952455344696420493F7C20676574...          F  ...
# 10     57454C4C5344696420493F7C2067657420746869732072...          M  ...
# 11     4E454C534F4E44696420493F7C20676574207468697320...          F  ...
# 12     415348544F4E44696420493F7C20676574207468697320...          M  ...
# 17     59414F44696420493F7C20676574207468697320726967...          M  ...
# 18     59414F44696420493F7C20676574207468697320726967...          M  ...
# 19     4652454E434844696420493F7C20676574207468697320...          M  ...
# 20     4652454E434844696420493F7C20676574207468697320...          M  ...
# 21     4652454E434844696420493F7C20676574207468697320...          F  ...
# 22     4652454E434844696420493F7C20676574207468697320...          F  ...
# 23     5045544552534F4E44696420493F7C2067657420746869...          F  ...
# 24     4B414C494E4F534B4944696420493F7C20676574207468...          F  ...
# 25     4B414C494E4F534B4944696420493F7C20676574207468...          F  ...
# 26     4E454C534F4E44696420493F7C20676574207468697320...          M  ...
# 27     4E454C534F4E44696420493F7C20676574207468697320...          M  ...
# 28     42494E445548414953484A5244696420493F7C20676574...          M  ...
# 29     42494E445548414953484A5244696420493F7C20676574...          M  ...
# 30     4341425245524144696420493F7C206765742074686973...          M  ...
# 31     4341425245524144696420493F7C206765742074686973...          M  ...
# 34     4D494C4C5344696420493F7C2067657420746869732072...          F  ...
# 35     4D494C4C5344696420493F7C2067657420746869732072...          F  ...
# ...                                                  ...        ...  ...
# 34510  53494D4F4E44696420493F7C2067657420746869732072...          M  ...
# 34511  53494D4F4E44696420493F7C2067657420746869732072...          M  ...
# 34512  434F4E4E454C4C44696420493F7C206765742074686973...          F  ...
# 34513  434F4E4E454C4C44696420493F7C206765742074686973...          F  ...
# 34514  434F4E4E454C4C44696420493F7C206765742074686973...          F  ...
# 34515  434F4E4E454C4C44696420493F7C206765742074686973...          F  ...
# 34516  42524F574E44696420493F7C2067657420746869732072...          F  ...
# 34517  42524F574E44696420493F7C2067657420746869732072...          F  ...
# 34518  4449584F4E44696420493F7C2067657420746869732072...          F  ...
# 34519  4449584F4E44696420493F7C2067657420746869732072...          F  ...
# 34520  4D454852494E4744696420493F7C206765742074686973...          M  ...
# 34521  4D454852494E4744696420493F7C206765742074686973...          M  ...
# 34526  4D454852494E4744696420493F7C206765742074686973...          F  ...
# 34527  4D454852494E4744696420493F7C206765742074686973...          F  ...
# 34528  4348414C5550534B5944696420493F7C20676574207468...          F  ...
# 34529  4348414C5550534B5944696420493F7C20676574207468...          F  ...
# 34530  4252454544454E44696420493F7C206765742074686973...          M  ...
# 34531  4252454544454E44696420493F7C206765742074686973...          M  ...
# 34532  4252454544454E44696420493F7C206765742074686973...          F  ...
# 34533  4252454544454E44696420493F7C206765742074686973...          F  ...
# 34534  59414E4744696420493F7C206765742074686973207269...          F  ...
# 34535  4D4F4E544F594147415243494144696420493F7C206765...          F  ...
# 34536  554E47455244696420493F7C2067657420746869732072...          F  ...
# 34537  554E47455244696420493F7C2067657420746869732072...          M  ...
# 34538  54414C4D41474544696420493F7C206765742074686973...          F  ...
# 34539  54414C4D41474544696420493F7C206765742074686973...          F  ...
# 34540  54414C4D41474544696420493F7C206765742074686973...          F  ...
# 34541  54414C4D41474544696420493F7C206765742074686973...          F  ...
# 34542  54414C4D41474544696420493F7C206765742074686973...          M  ...
# 34543  54414C4D41474544696420493F7C206765742074686973...          M  ...
#
#        TotalDocAmt  UFlyRewardsNumber UflyMemberStatus CardHolder  \
# 0           276.20                0.0         non-ufly        NaN
# 1           276.20                0.0         non-ufly        NaN
# 2             0.00                0.0         non-ufly        NaN
# 3             0.00                0.0         non-ufly        NaN
# 4           178.20        196189803.0         Standard      False
# 5           178.20        196189803.0         Standard      False
# 6             0.00                0.0         non-ufly        NaN
# 7           110.00                0.0         non-ufly        NaN
# 8           420.20        102080090.0         Standard      False
# 9           420.20        102080090.0         Standard      False
# 10          521.28                0.0         non-ufly        NaN
# 11           60.00                0.0         non-ufly        NaN
# 12          762.20                0.0         non-ufly        NaN
# 17          223.80        210569100.0         Standard      False
# 18          223.80        210569100.0         Standard      False
# 19          384.60        202559302.0         Standard      False
# 20          384.60        202559302.0         Standard      False
# 21          384.60        202559313.0         Standard      False
# 22          384.60        202559313.0         Standard      False
# 23          170.00                0.0         non-ufly        NaN
# 24          464.58                0.0         non-ufly        NaN
# 25          464.58                0.0         non-ufly        NaN
# 26          464.58                0.0         non-ufly        NaN
# 27          464.58                0.0         non-ufly        NaN
# 28          411.60                0.0         non-ufly        NaN
# 29          411.60                0.0         non-ufly        NaN
# 30          420.20        202001505.0         Standard      False
# 31          420.20        202001505.0         Standard      False
# 34          377.80        201417392.0         Standard      False
# 35          377.80        201417392.0         Standard      False
# ...            ...                ...              ...        ...
# 34510       317.80        202287536.0         Standard      False
# 34511       317.80        202287536.0         Standard      False
# 34512       357.80                0.0         non-ufly        NaN
# 34513       357.80                0.0         non-ufly        NaN
# 34514       357.80                0.0         non-ufly        NaN
# 34515       357.80                0.0         non-ufly        NaN
# 34516       216.00        202311152.0         Standard      False
# 34517       216.00        202311152.0         Standard      False
# 34518         0.00                0.0         non-ufly        NaN
# 34519         0.00                0.0         non-ufly        NaN
# 34520       539.99                0.0         non-ufly        NaN
# 34521       539.99                0.0         non-ufly        NaN
# 34526       539.99                0.0         non-ufly        NaN
# 34527       539.99                0.0         non-ufly        NaN
# 34528       386.80                0.0         non-ufly        NaN
# 34529       386.80                0.0         non-ufly        NaN
# 34530         0.00                0.0         non-ufly        NaN
# 34531         0.00                0.0         non-ufly        NaN
# 34532         0.00                0.0         non-ufly        NaN
# 34533         0.00                0.0         non-ufly        NaN
# 34534       129.10                0.0         non-ufly        NaN
# 34535       207.90                0.0         non-ufly        NaN
# 34536       129.00        200269963.0         Standard      False
# 34537       129.00        200269941.0         Standard      False
# 34538       520.00                0.0         non-ufly        NaN
# 34539       520.00                0.0         non-ufly        NaN
# 34540       520.00                0.0         non-ufly        NaN
# 34541       520.00                0.0         non-ufly        NaN
# 34542       520.00                0.0         non-ufly        NaN
# 34543       520.00                0.0         non-ufly        NaN
#
#       BookedProduct EnrollDate  MarketingFlightNbr  MarketingAirlineCode  \
# 0               NaN        NaN                 392                    SY
# 1               NaN        NaN                 395                    SY
# 2              DSNY        NaN                 342                    SY
# 3              DSNY        NaN                 341                    SY
# 4               NaN    39:04.0                 422                    SY
# 5               NaN    39:04.0                 421                    SY
# 6             SALCL        NaN                 288                    SY
# 7               NaN        NaN                 421                    SY
# 8            SSWMIR    00:00.0                 341                    SY
# 9            SSWMIR    00:00.0                 342                    SY
# 10               UP        NaN                 426                    SY
# 11              NaN        NaN                 174                    SY
# 12               UP        NaN                 609                    SY
# 17              NaN    03:52.0                 265                    SY
# 18              NaN    03:52.0                 268                    SY
# 19              NaN    08:19.0                 396                    SY
# 20              NaN    08:19.0                 395                    SY
# 21              NaN    09:43.0                 396                    SY
# 22              NaN    09:43.0                 395                    SY
# 23              NaN        NaN                 283                    SY
# 24              SCV        NaN                 582                    SY
# 25              SCV        NaN                 571                    SY
# 26              SCV        NaN                 582                    SY
# 27              SCV        NaN                 571                    SY
# 28              NaN        NaN                 422                    SY
# 29              NaN        NaN                 253                    SY
# 30           SSWMIR    43:14.0                 341                    SY
# 31           SSWMIR    43:14.0                 342                    SY
# 34              NaN    18:06.0                 421                    SY
# 35              NaN    18:06.0                 430                    SY
# ...             ...        ...                 ...                   ...
# 34510           NaN    52:32.0                 425                    SY
# 34511           NaN    52:32.0                 426                    SY
# 34512           NaN        NaN                 344                    SY
# 34513           NaN        NaN                 341                    SY
# 34514           NaN        NaN                 341                    SY
# 34515           NaN        NaN                 344                    SY
# 34516           NaN    03:02.0                 503                    SY
# 34517           NaN    03:02.0                 504                    SY
# 34518           EXP        NaN                 107                    SY
# 34519           EXP        NaN                 106                    SY
# 34520           SCV        NaN                 571                    SY
# 34521           SCV        NaN                 582                    SY
# 34526           SCV        NaN                 582                    SY
# 34527           SCV        NaN                 571                    SY
# 34528           NaN        NaN                 422                    SY
# 34529           NaN        NaN                 423                    SY
# 34530        BSGTIX        NaN                 503                    SY
# 34531        BSGTIX        NaN                 504                    SY
# 34532        BSGTIX        NaN                 504                    SY
# 34533        BSGTIX        NaN                 503                    SY
# 34534        SSWMIR        NaN                 235                    SY
# 34535           NaN        NaN                 426                    SY
# 34536        SSWMIR    15:33.0                 383                    SY
# 34537        SSWMIR    12:35.0                 383                    SY
# 34538        SSWMIR        NaN                 340                    SY
# 34539        SSWMIR        NaN                 341                    SY
# 34540        SSWMIR        NaN                 341                    SY
# 34541        SSWMIR        NaN                 340                    SY
# 34542        SSWMIR        NaN                 341                    SY
# 34543        SSWMIR        NaN                 340                    SY
#
#        StopoverCode min
# 0               NaN   1
# 1                 O   1
# 2                 O   1
# 3               NaN   1
# 4                 O   1
# 5                 O   1
# 6               NaN   1
# 7               NaN   1
# 8               NaN   1
# 9                 O   1
# 10              NaN   1
# 11              NaN   1
# 12              NaN   1
# 17                O   1
# 18              NaN   1
# 19                O   1
# 20              NaN   1
# 21                O   1
# 22              NaN   1
# 23              NaN   1
# 24                O   1
# 25              NaN   1
# 26                O   1
# 27              NaN   1
# 28              NaN   1
# 29                X   1
# 30              NaN   1
# 31                O   1
# 34              NaN   1
# 35                O   1
# ...             ...  ..
# 34510             O   1
# 34511           NaN   1
# 34512             O   1
# 34513           NaN   1
# 34514           NaN   1
# 34515             O   1
# 34516           NaN   1
# 34517             O   1
# 34518             O   1
# 34519             O   1
# 34520           NaN   1
# 34521             O   1
# 34526             O   1
# 34527           NaN   1
# 34528           NaN   1
# 34529             O   1
# 34530           NaN   1
# 34531             O   1
# 34532             O   1
# 34533           NaN   1
# 34534           NaN   1
# 34535             O   1
# 34536           NaN   1
# 34537           NaN   1
# 34538             O   1
# 34539           NaN   1
# 34540           NaN   1
# 34541             O   1
# 34542           NaN   1
# 34543             O   1
#
# [31551 rows x 27 columns]

# %%
SY_customer = group[group['min'] == 1]

# %%
SY_customer.shape
# Out:
# (31448, 27)

# %%
# Create a unique customer ID by concatenating name, gender and birthday
SY_customer['uid'] = SY_customer['PaxName'].map(str) + '_' + SY_customer['GenderCode'].map(str) + '_' + SY_customer['birthdateid'].map(str)

# %%
SY_customer.head()
# Out:
#   PNRLocatorID     TicketNum  CouponSeqNbr ServiceStartCity ServiceEndCity  \
# 0       AADJKH  3.377510e+12             1              SFO            MSP
# 1       AADJKH  3.377510e+12             2              MSP            SFO
# 2       AAFCUE  3.377510e+12             2              MCO            MSP
# 3       AAFCUE  3.377510e+12             1              MSP            MCO
# 4       AAFDZS  3.377410e+12             2              LAX            MSP
#
#   PNRCreateDate ServiceStartDate PaxName  \
# 0    11/10/2014        12/8/2014  SHORLE
# 1    11/10/2014       12/11/2014  SHORLE
# 2     12/1/2014       12/21/2014  SOEFEV
# 3     12/1/2014       12/17/2014  SOEFEV
# 4     10/9/2014       10/30/2014  NEUMJO
#
#                                        EncryptedName GenderCode  ...  \
# 0  53484F52455944696420493F7C20676574207468697320...          F  ...
# 1  53484F52455944696420493F7C20676574207468697320...          F  ...
# 2  534F4546464B455244696420493F7C2067657420746869...          M  ...
# 3  534F4546464B455244696420493F7C2067657420746869...          M  ...
# 4  4E45554D414E44696420493F7C20676574207468697320...          M  ...
#
#    UFlyRewardsNumber  UflyMemberStatus CardHolder BookedProduct EnrollDate  \
# 0                0.0          non-ufly        NaN           NaN        NaN
# 1                0.0          non-ufly        NaN           NaN        NaN
# 2                0.0          non-ufly        NaN          DSNY        NaN
# 3                0.0          non-ufly        NaN          DSNY        NaN
# 4        196189803.0          Standard      False           NaN    39:04.0
#
#   MarketingFlightNbr  MarketingAirlineCode  StopoverCode  min  \
# 0                392                    SY           NaN    1
# 1                395                    SY             O    1
# 2                342                    SY             O    1
# 3                341                    SY           NaN    1
# 4                422                    SY             O    1
#
#                 uid
# 0  SHORLE_F_39225.0
# 1  SHORLE_F_39225.0
# 2  SOEFEV_M_56218.0
# 3  SOEFEV_M_56218.0
# 4  NEUMJO_M_46051.0
#
# [5 rows x 28 columns]

# %%
# creating a new categorical variable "age_group" with the following posisble values: 
# "0-17", "18-24", "25-34", "35-54", "55+" and "N/A"
bins = [0,18,25,35,55,np.inf]
labels = ["0-17", "18-24", "25-34", "35-54", "55+"]
SY_customer['age_group'] = pd.cut(SY_customer['Age'], bins=bins, labels=labels, right=False)

# %%
SY_customer['ServiceStartDate'] = pd.to_datetime(SY_customer['ServiceStartDate'])
SY_customer['PNRCreateDate'] = pd.to_datetime(SY_customer['PNRCreateDate'])

# %%
# For a given PNR, figure out true origin city (source of first leg) 
# Sorting within groups based on column "CouponSeqNbr":
SY_customer['true_origin']=SY_customer.sort_values(['PNRLocatorID', 'PaxName', 'CouponSeqNbr', 'ServiceStartDate']).groupby(['PNRLocatorID', 'PaxName'])['ServiceStartCity'].transform(lambda x: x.iloc[0])

# %%
# For a given PNR, figure out final destination (target of last leg)
SY_customer['final_destination']=SY_customer.sort_values(['PNRLocatorID', 'PaxName', 'CouponSeqNbr', 'ServiceStartDate']).groupby(['PNRLocatorID', 'PaxName'])['ServiceEndCity'].transform(lambda x: x.iloc[-1])

# %%
# Is the booking a round-trip or one-way?
SY_customer.loc[SY_customer['true_origin'] == SY_customer['final_destination'], 'roundtrip'] = True
SY_customer.loc[SY_customer['true_origin'] != SY_customer['final_destination'], 'roundtrip'] = False

# %%
# What is the size of the group?
SY_customer['group_size'] = SY_customer.groupby('PNRLocatorID')['uid'].transform('nunique')

# %%
# Create a binary indicator "group" corresponding to whether it was a group or single party traveling.
SY_customer.loc[SY_customer['group_size'] > 1, 'group'] = True
SY_customer.loc[SY_customer['group_size'] <= 1, 'group'] = False

# %%
import datetime

# %%
# Figure out which calendar quarter the trip took place in.
bins = [0,4,7,10,13]
labels = ["Q1", "Q2", "Q3", "Q4"]
SY_customer['seasonality'] = pd.cut(SY_customer['ServiceStartDate'].dt.month, bins=bins, labels=labels, right=False)

# %%
# How many days in advance was the trip booked?
SY_customer['days_pre_booked'] = SY_customer['ServiceStartDate'] - SY_customer['PNRCreateDate']

# %%
SY_customer.head()
# Out:
#   PNRLocatorID     TicketNum  CouponSeqNbr ServiceStartCity ServiceEndCity  \
# 0       AADJKH  3.377510e+12             1              SFO            MSP
# 1       AADJKH  3.377510e+12             2              MSP            SFO
# 2       AAFCUE  3.377510e+12             2              MCO            MSP
# 3       AAFCUE  3.377510e+12             1              MSP            MCO
# 4       AAFDZS  3.377410e+12             2              LAX            MSP
#
#   PNRCreateDate ServiceStartDate PaxName  \
# 0    2014-11-10       2014-12-08  SHORLE
# 1    2014-11-10       2014-12-11  SHORLE
# 2    2014-12-01       2014-12-21  SOEFEV
# 3    2014-12-01       2014-12-17  SOEFEV
# 4    2014-10-09       2014-10-30  NEUMJO
#
#                                        EncryptedName GenderCode  ...  min  \
# 0  53484F52455944696420493F7C20676574207468697320...          F  ...    1
# 1  53484F52455944696420493F7C20676574207468697320...          F  ...    1
# 2  534F4546464B455244696420493F7C2067657420746869...          M  ...    1
# 3  534F4546464B455244696420493F7C2067657420746869...          M  ...    1
# 4  4E45554D414E44696420493F7C20676574207468697320...          M  ...    1
#
#                 uid age_group true_origin true_destination final_destination  \
# 0  SHORLE_F_39225.0       55+         SFO              SFO               SFO
# 1  SHORLE_F_39225.0       55+         SFO              SFO               SFO
# 2  SOEFEV_M_56218.0      0-17         MSP              MSP               MSP
# 3  SOEFEV_M_56218.0      0-17         MSP              MSP               MSP
# 4  NEUMJO_M_46051.0     35-54         MSP              MSP               MSP
#
#    roundtrip  group_size  group days_pre_booked
# 0       True           1  False         28 days
# 1       True           1  False         31 days
# 2       True           1  False         20 days
# 3       True           1  False         16 days
# 4       True           1  False         21 days
#
# [5 rows x 36 columns]

# %%
SY_customer.to_csv("SY_customer.csv")
